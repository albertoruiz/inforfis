# %% [markdown]
# # Tarea 5
#
# Nombre:  **Nombre Apellido Apellido**
#
# x/10/2020

# %% [markdown]
# ## Repaso

# %% [markdown]
# Estudia detenidamente el notebook [matplotlib.ipynb](matplotlib.ipynb). Reproduce los diferentes gráficos haciendo modificaciones para ver el resultado. (Los apartados con asterisco pueden saltarse en una primera lectura.) En [este notebook](grafica.ipynb) se muestra la construcción de una gráfica paso a paso.

# %% [markdown]
# ## Ejercicios

# %% [markdown]
# Resuelve los siguientes ejercicios, usando únicamente los conceptos explicados en clase hasta ahora.

# %% [markdown]
# **1)** Dibuja una [campana de Gauss](https://en.wikipedia.org/wiki/Normal_distribution).

# %% [markdown]
# **2)** Modifica la gráfica anterior para obtener algo parecido a esto ([paquete de ondas](https://en.wikipedia.org/wiki/Wave_packet)):
#
# ![packet.png](attachment:packet.png)

# %% [markdown]
# **3)** Crea un gráfico **idéntico** al siguiente y guárdalo en un archivo pdf:
#
# ![rayas.png](attachment:rayas.png)

# %% [markdown]
# **4)** Dibuja una espiral logarítmica.

# %% [markdown]
# **5**) Dibuja algo como esto:

# %%
#

# %% [markdown]
# **6)** Dibuja una [rosa](http://en.wikipedia.org/wiki/Rose_%28mathematics%29).

# %% [markdown]
# **7)** Dibuja en una figura la gráfica de la función $f(x)=sin(x)$ (en negro, con trazo grueso), junto con los tres polinomios [de Taylor](https://en.wikipedia.org/wiki/Taylor_series)  siguientes(en diferentes colores, con trazo fino). Muestra el intervalo $-1 \leq x \leq 4$ y fija el eje vertical entre -2 y 2.
#
# \begin{aligned}\\
# a(x) &= x\\
# b(x) &= x - \frac{x^3}{6}\\
# c(x) &= x - \frac{x^3}{6} + \frac{x^5}{120}
# \end{aligned}

# %%
#

# %% [markdown]
# **8)** Dibuja [figuras de Lissajous](http://en.wikipedia.org/wiki/Lissajous_curve).

# %% [markdown]
# **9)** Dibuja puntos uniformemente distribuidos dentro del círculo unidad.

# %% [markdown]
# **10**) Dibuja una circunferencia en el plano de radio $r=1$ y marca tres puntos elegidos al azar en ella. (Piensa en polares.)

# %% [markdown]
# **11)** Escribe una función `star(n,d)` para construir estas figuras:

# %%
star(1,5)

# %%
star(2,5)

# %%
star(4,7)

# %% [markdown]
# **12)** Representa gráficamente la densidad de probabilidad normal y su distribución acumulada y muestra sus valores en un punto concreto, como se muestra a continuación. Puedes usar `norm` del módulo `scipy.stats`, que proporciona `norm.pdf()` y `norm.cdf()`. El sombreado se consigue con `plt.fill_between(x,y1,y2, color )`.

# %%
#

# %% [markdown]
# **13)** Añade interactividad a la figura anterior para cambiar el valor de ejemplo con un "trackbar".

# %% [markdown]
# **14)** Dibuja un polígono regular de $n$ lados que se apoya en un segmento dado $(x_1,y_1)$ $(x_2,y_2)$.

# %% [markdown]
# **15)** Dados tres puntos del plano, dibuja la circunferencia que pasa por ellos.

# %% [markdown]
# **16)** Crea libremente una figura de tu elección.

# %% [markdown]
# **17)** Crea una animación.
