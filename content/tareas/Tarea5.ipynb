# %% [markdown]
# Nombre:
#
# Fecha:
#
# ---

# %% [markdown]
# # Tarea 5

# %% [markdown]
# Estudia detenidamente el notebook [matplotlib.ipynb](../matplotlib.ipynb). Reproduce los diferentes gráficos haciendo modificaciones para ver el resultado. (Los apartados con asterisco pueden saltarse en una primera lectura.) En [este notebook](grafica.ipynb) se muestra la construcción de una gráfica paso a paso.

# %% [markdown]
# Resuelve los siguientes ejercicios, usando únicamente los conceptos explicados en clase hasta ahora.

# %% [markdown]
# ## Campana de Gauss

# %% [markdown]
# Dibuja una [campana de Gauss](https://en.wikipedia.org/wiki/Normal_distribution).

# %%
import numpy as np
import matplotlib.pyplot as plt
plt.rc('figure', figsize=(5,3))

# %%
# Escribe aquí tu código para conseguir algo parecido a esto:

# %% [markdown]
# ## Paquete de ondas

# %% [markdown]
# Modifica la gráfica anterior para obtener algo parecido a esto ([paquete de ondas](https://en.wikipedia.org/wiki/Wave_packet)):

# %%
# Escribe aquí tu solución

# %% [markdown]
# ## Múltiples líneas

# %% [markdown]
# Crea un gráfico **idéntico** al siguiente y guárdalo en un archivo pdf:

# %%
# Escribe aquí tu solución

# %% [markdown]
# ## Espiral logarítmica

# %% [markdown]
# Dibuja una espiral logarítmica.

# %%
# Escribe aquí tu solución

# %% [markdown]
# ## Hélice-cono

# %% [markdown]
# Dibuja algo como esto:

# %%
# Escribe aquí tu solución

# %% [markdown]
# ## Rosa

# %% [markdown]
# Dibuja una [rosa](http://en.wikipedia.org/wiki/Rose_%28mathematics%29).

# %%
# Escribe aquí tu solución

# %% [markdown]
# ## Series de Taylor

# %% [markdown]
# Dibuja en una figura la gráfica de la función $f(x)=sin(x)$ (en negro, con trazo grueso), junto con los tres polinomios [de Taylor](https://en.wikipedia.org/wiki/Taylor_series)  siguientes(en diferentes colores, con trazo fino). Muestra el intervalo $-1 \leq x \leq 4$ y fija el eje vertical entre -2 y 2.
#
# \begin{aligned}\\
# a(x) &= x\\
# b(x) &= x - \frac{x^3}{6}\\
# c(x) &= x - \frac{x^3}{6} + \frac{x^5}{120}
# \end{aligned}

# %%
# Escribe aquí tu solución

# %% [markdown]
# ## Lissajous

# %% [markdown]
# Dibuja [figuras de Lissajous](http://en.wikipedia.org/wiki/Lissajous_curve).

# %% [markdown]
# ## Puntos aleatorios en disco

# %% [markdown]
# Dibuja puntos uniformemente distribuidos dentro del círculo unidad.

# %%
# Escribe aquí tu solución

# %% [markdown]
# ## Puntos aleatorios en circunferencia

# %% [markdown]
# Dibuja una circunferencia en el plano de radio $r=1$ y marca tres puntos elegidos al azar en ella. (Piensa en polares.)

# %% [markdown]
# ## Polígonos regulares

# %% [markdown]
# Escribe una función `star(n,d)` para construir estas figuras:

# %%
# Escribe aquí tu solución

# %%
star(1,5)

# %%
star(2,5)

# %%
star(4,7)

# %% [markdown]
# ## Función de error

# %% [markdown]
# Representa gráficamente la densidad de probabilidad normal y su distribución acumulada y muestra sus valores en un punto concreto, como se muestra a continuación. Puedes usar `norm` del módulo `scipy.stats`, que proporciona `norm.pdf()` y `norm.cdf()`. El sombreado se consigue con `plt.fill_between(x,y1,y2, color )`.

# %%
# Escribe aquí tu solución

# %% [markdown]
# ## Interactividad

# %% [markdown]
# Añade interactividad a la figura anterior para cambiar el valor de ejemplo con un "trackbar".

# %% [markdown]
# ## Polígono regular en posición arbitraria

# %% [markdown]
# Dibuja un polígono regular de $n$ lados que se apoya en un segmento dado $(x_1,y_1)$ $(x_2,y_2)$.

# %% [markdown]
# ## Circunferencia por tres puntos

# %% [markdown]
# Dados tres puntos del plano, dibuja la circunferencia que pasa por ellos.

# %% [markdown]
# ## Gráfica libre

# %% [markdown]
# Crea libremente una figura de tu elección.

# %% [markdown]
# ## Animación

# %% [markdown]
# Crea libremente una animación.
